# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasgini22/exercicios_saulo/blob/main/aula26_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 02: Estruturas de Decisão**
# Até agora, nossos programas executaram todas as linhas de código, de cima para baixo. Mas e se a gente só quisesse executar um código se uma condição for verdadeira? Para isso usamos as estruturas de decisão, lideradas pelo comando if (se)

# %% [markdown]
# # **1. O comando if**
# O if verifica se uma afirmação é Verdadeira (True) ou Falsa (False). Se for Verdadeira, o bloco de código dentro do if é executado.

# %%
idade = int(input("Digite sua idade: "))
if (idade >= 10):
    print("inteira")
else:
    print("meia")
# Out:
# Digite sua idade: 22
# inteira

# %%
idade = int(input("digite sua idade:"))
1
# Lê-se: Se idade for maior ou igual a 18...
if idade >= 18:
    print("Você é maior de idade.")
    print("Pode entrar na festa!")

print("Fim do programa.")
# Out:
# digite sua idade:18
# Você é maior de idade.
# Pode entrar na festa!
# Fim do programa.

# %% [markdown]
# **Atenção à indentação!** No Brasil, chamamos de "espaçamento". O Python usa espaços no começo da linha (indentação) para saber quais linhas de código pertencem ao if. Tudo que estiver alinhado com espaços para dentro faz parte daquele bloco.
#
# ### Operadores de Comparação:
# * `==` : Igual
# * `!=` : Diferente
# * `>`  : Maior que
# * `<`  : Menor que
# * `>=` : Maior ou igual a
# * `<=` : Menor ou igual a

# %% [markdown]
# ## 2. O comando `else` (Senão)
#
# Se a condição do `if` não for verdadeira, podemos usar o `else` para realizar outra ação.

# %%
nota = float(input ("Digite a nota do aluno: "))

if nota >= 7:
    print("Você foi Aprovado!")
else:
    print("Você foi Reprovado.")
# Out:
# Digite a nota do aluno: 8
# Você foi Aprovado!

# %% [markdown]
# * IF SOZINHO = 1 POSSIBILIDADE
# * IF + ELSE = 2 POSSIBILIDADE
# * ELIF = JUNCAO DE ELSE + IF (MAIS DE 2 POSSIBILIDADE)

# %% [markdown]
# ## 3. O comando `elif` (Senão Se)
#
# Às vezes, temos mais de duas situações possíveis. Por exemplo, num semáforo de trânsito, temos verde, amarelo e vermelho. Usamos o `elif` para testar várias condições em sequência.

# %%
cor = input ("Digite a cor do semáforo (verde/amarelo/vermelho): ").lower()
if cor == "verde":
    print("Siga em frente!")
elif cor == "amarelo":
    print("Atenção!")
elif cor == "vermelho":
    print("Pare!")
else:
    print("Cor inválida.")
# Out:
# Digite a cor do semáforo (verde/amarelo/vermelho): verde
# Siga em frente!

# %% [markdown]
# No código acima, usamos `.lower()` ao final do `input()` para converter o que o usuário digitou para letras minúsculas (assim identificamos 'Verde', 'VERDE' ou 'verde' da mesma forma).

# %% [markdown]
# ## Exercício de Fixação
# Crie um código que pergunte um número inteiro ao usuário e informe na tela se esse número é **Positivo, Negativo ou Zero**.

# %%
numero = int(input("Digite um número inteiro: "))
if (numero == 0):
    print("Zero")
elif (numero > 0):
    print("Positivo")
else:
    print("Negativo")
    # Escreva seu código de validação if/elif/else aqui
# Out:
# Digite um número inteiro: -1
# Negativo

# %% [markdown]
# # **Aula 03**: Estruturas de Decisão com Álgebra Booleana
#
# Na aula anterior, aprendemos a fazer uma única pergunta com o `if` (ex: `idade >= 18`).
# E se precisarmos que **duas coisas** sejam verdadeiras ao mesmo tempo? Ou se precisarmos que pelo menos **uma de duas** coisas seja verdade?
# É aqui que entram os operadores lógicos: `and` (E), `or` (OU) e `not` (NÃO).

# %% [markdown]
# ## 1. O operador `and` (E)
#
# Com o `and`, a condição completa só será verdadeira se **TODAS as partes forem verdadeiras**. Pense em um sistema de login: você precisa acertar o usuário E a senha.

# %%
usuario_correto = "gordo"
senha_correta = "eliana"
magico = 22

usuario = input("Usuário: ")
senha = input("Senha: ")
magico_correto = int(input("Magico: "))

if usuario == usuario_correto and senha == senha_correta and magico == magico_correto :
    print("Login efetuado com sucesso!")
else:
    print("Usuário ou senha incorretos.")
# Out:
# Usuário: gordo
# Senha: eliana
# Magico: 2
# Usuário ou senha incorretos.

# %% [markdown]
# Outro exemplo clássico do `and` é verificar se um número está **entre** dois valores (um intervalo).

# %%
# O voto no Brasil é obrigatório entre 18 (incluso) e menos de 70 anos.

idade = int(input("Digite sua idade: "))

if idade >= 18 and idade < 70:
  print("Seu voto é obrigatório!")
else:
  print("Seu voto não é obrigatório.")
# Out:
# Digite sua idade: 22
# Seu voto é obrigatório!

# %% [markdown]
# *Dica Ninja Python:* O Python permite escrever a Matemática básica de um jeito mais próximo do papel para representar intervalos. A linha acima poderia ser escrita também como: `if 18 <= idade < 70:`.

# %% [markdown]
# ## 2. O operador `or` (OU)
#
# Com o `or`, a condição completa será verdadeira se **PELO MENOS UMA** das partes for verdadeira. Só será falso se ambas as partes estiverem falsas.

# %%
dia_da_semana = input("Que dia da semana é hoje? ").lower()

if dia_da_semana == "sábado" or dia_da_semana == "domingo" or dia_da_semana == "sexta":
    print("Eba! É final de semana!")
else:
    print("Dia útil. Vamos trabalhar/estudar.")
# Out:
# Que dia da semana é hoje? sexta
# Eba! É final de semana!

# %% [markdown]
# ## 3. O operador `not` (NÃO)
#
# O `not` simplesmente **inverte** o valor lógico. Se era Verdade, vira Falso. Se era Falso, vira Verdade.
# É muito útil para verificações do tipo "se NÃO está vazio" ou "se a permissão NÃO foi concedida".

# %%
chovendo = True

if not chovendo:
    print("Vamos ao parque!")
else:
    print("Vamos assistir a um filme em casa.")
# Out:
# Vamos assistir a um filme em casa.

# %%
nome = input("Digite seu nome: ")

# O Python permite inverter a comparação de Igualdade.
# `!=` é a mesma coisa que fazer `not (variavel == valor)`
if nome != "Visitante":
    print(f"Bem vindo de volta, {nome}!")
# Out:
# Digite seu nome: lucas
# Bem vindo de volta, lucas!

# %% [markdown]
# ## Exercício de Fixação
#
# Um parque de diversões tem um brinquedo radical.
# Para entrar nele, a pessoa precisa:
# 1. Ter pelo menos 1.50m de altura (`altura >= 1.50`)
# 2. Ter 12 anos ou mais (`idade >= 12`)
#
# Porém, se a pessoa estiver acompanhada dos pais, basta ter 1.30m de altura (independente da idade).
#
# Escreva as perguntas usando `input()` e faça a árvore de decisão `if/elif/else` com `and/or` para liberar ou barrar a pessoa.

# %%
# Escreva sua solução aqui!

altura = float(input ("Qual sua altura:"))
idade = int(input ("qual sua idade:"))

if(altura >= 1.50 and idade >= 12):
  print("Liberado para brincar")
else:
  print("Bloqueado para brincar")

# %%
# Escreva sua solução aqui!

altura = float(input ("Qual sua altura:"))
idade = int(input ("qual sua idade:"))
acompanhado = True

if(altura >= 1.50 and idade >= 12):
  print("Liberado para brincar")
elif (altura >= 1.30 and acompanhado):
  print("Liberado para brincar")
else:
  print("Bloqueado para brincar")
